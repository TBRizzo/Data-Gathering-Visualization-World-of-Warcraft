# %% [markdown]
# # COLLECTING DATA FROM RAIDER.IO (WOW RANKINGS WEBSITE)

# %% [markdown]
# ## API Raider.io
#
# API obtained from 'https://raider.io/api#/mythic_plus/getApiV1MythicplusRuns', which generates the API's URL according to your needs.

# %%
import requests
import pandas as pd
import json

# %% [markdown]
# ## The API is public, so the connection process was pretty straight forward.

# %%
#checking the structure of the website. This way we could see that each key "rankings" was a page from the website.
response = requests.get('https://raider.io/api/v1/mythic-plus/runs?season=season-7.3.0&region=world&dungeon=all&page=0')
results = response.json()
results
# Out:
# {'rankings': [{'rank': 1,
#    'score': 381.7,
#    'run': {'season': 'season-7.3.0',
#     'status': 'finished',
#     'dungeon': {'id': 999998,
#      'name': 'Return to Karazhan: Lower',
#      'short_name': 'LOWR',
#      'slug': 'return-to-karazhan-lower',
#      'expansion_id': 6,
#      'patch': '7.2',
#      'keystone_timer_ms': 2520999,
#      'num_bosses': 4,
#      'group_finder_activity_id': 471},
#     'keystone_run_id': 3836767,
#     'mythic_level': 24,
#     'clear_time_ms': 2196695,
#     'keystone_time_ms': 2340999,
#     'completed_at': '2017-11-21T05:17:38.000Z',
#     'num_chests': 1,
#     'time_remaining_ms': 144304,
#     'logged_run_id': None,
#     'weekly_modifiers': [{'id': 8,
#       'icon': 'spell_shadow_bloodboil',
#       'name': 'Sanguine',
#       'description': 'When slain, non-boss enemies leave behind a lingering pool of ichor that heals their allies and damages players.'},
#      {'id': 12,
#       'icon': 'ability_backstab',
#       'name': 'Grievous',
#       'description': 'Injured players suffer increasing damage over time until healed.'},
#      {'id': 10,
#       'icon': 'ability_toughness',
#       'name': 'Fortified',
#       'description': 'Non-boss enemies have 20% more health and inflict up to 30% increased damage.'}],
#     'num_modifiers_active': 3,
#     'faction': 'horde',
#     'deleted_at': None,
#     'keystone_platoon_id': None,
#     'keystone_team_id': 5441777,
#     'roster': [{'character': {'id': 1744,
#        'persona_id': 508,
#        'name': 'Imfiredup-1744',
#        'class': {'id': 8, 'name': 'Mage', 'slug': 'mage'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 110,
#        'spec': {'name': 'Fire', 'slug': 'fire'},
#        'path': '/characters/us/illidan/Imfiredup-1744',
#        'realm': {'id': 369,
#         'connectedRealmId': 207,
#         'name': 'Illidan',
#         'altName': None,
#         'slug': 'illidan',
#         'altSlug': 'illidan',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 1282089,
#        'persona_id': 2678248,
#        'name': 'Zqs-1282089',
#        'class': {'id': 10, 'name': 'Monk', 'slug': 'monk'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 50,
#        'spec': {'name': 'Mistweaver', 'slug': 'mistweaver'},
#        'path': '/characters/us/tichondrius/Zqs-1282089',
#        'realm': {'id': 468,
#         'connectedRealmId': 236,
#         'name': 'Tichondrius',
#         'altName': None,
#         'slug': 'tichondrius',
#         'altSlug': 'tichondrius',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'tank'},
#      {'character': {'id': 9311198,
#        'persona_id': 2110136,
#        'name': 'Wafflesauce',
#        'class': {'id': 11, 'name': 'Druid', 'slug': 'druid'},
#        'race': {'id': 6,
#         'name': 'Tauren',
#         'slug': 'tauren',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 60,
#        'spec': {'name': 'Balance', 'slug': 'balance'},
#        'path': '/characters/us/tichondrius/Wafflesauce',
#        'realm': {'id': 468,
#         'connectedRealmId': 236,
#         'name': 'Tichondrius',
#         'altName': None,
#         'slug': 'tichondrius',
#         'altSlug': 'tichondrius',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': False,
#       'role': 'dps'},
#      {'character': {'id': 9545803,
#        'persona_id': 355504,
#        'name': 'Níghtfall-9545803',
#        'class': {'id': 9, 'name': 'Warlock', 'slug': 'warlock'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 60,
#        'spec': {'name': 'Affliction', 'slug': 'affliction'},
#        'path': '/characters/us/tichondrius/Níghtfall-9545803',
#        'realm': {'id': 468,
#         'connectedRealmId': 236,
#         'name': 'Tichondrius',
#         'altName': None,
#         'slug': 'tichondrius',
#         'altSlug': 'tichondrius',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 10279382,
#        'persona_id': 173963,
#        'name': 'Maset-10279382',
#        'class': {'id': 2, 'name': 'Paladin', 'slug': 'paladin'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 50,
#        'spec': {'name': 'Holy', 'slug': 'holy'},
#        'path': '/characters/us/thrall/Maset-10279382',
#        'realm': {'id': 465,
#         'connectedRealmId': 235,
#         'name': 'Thrall',
#         'altName': None,
#         'slug': 'thrall',
#         'altSlug': 'thrall',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'healer'}],
#     'platoon': None}},
#   {'rank': 2,
#    'score': 380.3,
#    'run': {'season': 'season-7.3.0',
#     'status': 'finished',
#     'dungeon': {'id': 8040,
#      'name': 'Eye of Azshara',
#      'short_name': 'EOA',
#      'slug': 'eye-of-azshara',
#      'expansion_id': 6,
#      'patch': '7.0',
#      'keystone_timer_ms': 2100999,
#      'num_bosses': 5,
#      'group_finder_activity_id': 459},
#     'keystone_run_id': 3788724,
#     'mythic_level': 24,
#     'clear_time_ms': 2062796,
#     'keystone_time_ms': 2100999,
#     'completed_at': '2017-11-19T22:45:20.000Z',
#     'num_chests': 1,
#     'time_remaining_ms': 38203,
#     'logged_run_id': None,
#     'weekly_modifiers': [{'id': 8,
#       'icon': 'spell_shadow_bloodboil',
#       'name': 'Sanguine',
#       'description': 'When slain, non-boss enemies leave behind a lingering pool of ichor that heals their allies and damages players.'},
#      {'id': 12,
#       'icon': 'ability_backstab',
#       'name': 'Grievous',
#       'description': 'Injured players suffer increasing damage over time until healed.'},
#      {'id': 10,
#       'icon': 'ability_toughness',
#       'name': 'Fortified',
#       'description': 'Non-boss enemies have 20% more health and inflict up to 30% increased damage.'}],
#     'num_modifiers_active': 3,
#     'faction': 'horde',
#     'deleted_at': None,
#     'keystone_platoon_id': None,
#     'keystone_team_id': 6649513,
#     'roster': [{'character': {'id': 1165923,
#        'persona_id': 2669705,
#        'name': 'Miraclestep-1165923',
#        'class': {'id': 4, 'name': 'Rogue', 'slug': 'rogue'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 50,
#        'spec': {'name': 'Assassination', 'slug': 'assassination'},
#        'path': '/characters/eu/stormscale/Miraclestep-1165923',
#        'realm': {'id': 713,
#         'connectedRealmId': 357,
#         'name': 'Stormscale',
#         'altName': None,
#         'slug': 'stormscale',
#         'altSlug': 'stormscale',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 4306794,
#        'persona_id': 3646890,
#        'name': 'Tasnaran-4306794',
#        'class': {'id': 11, 'name': 'Druid', 'slug': 'druid'},
#        'race': {'id': 6,
#         'name': 'Tauren',
#         'slug': 'tauren',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 50,
#        'spec': {'name': 'Restoration', 'slug': 'restoration'},
#        'path': '/characters/eu/twisting-nether/Tasnaran-4306794',
#        'realm': {'id': 739,
#         'connectedRealmId': 362,
#         'name': 'Twisting Nether',
#         'altName': None,
#         'slug': 'twisting-nether',
#         'altSlug': 'twisting-nether',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'healer'},
#      {'character': {'id': 7261250,
#        'persona_id': 1818682,
#        'name': 'Deepshades-7261250',
#        'class': {'id': 9, 'name': 'Warlock', 'slug': 'warlock'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 60,
#        'spec': {'name': 'Affliction', 'slug': 'affliction'},
#        'path': '/characters/eu/tarren-mill/Deepshades-7261250',
#        'realm': {'id': 719,
#         'connectedRealmId': 300,
#         'name': 'Tarren Mill',
#         'altName': None,
#         'slug': 'tarren-mill',
#         'altSlug': 'tarren-mill',
#         'locale': 'en_GB',
#         'isConnected': True},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 10681862,
#        'persona_id': 18349770,
#        'name': 'Landqvist-10681862',
#        'class': {'id': 1, 'name': 'Warrior', 'slug': 'warrior'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 50,
#        'spec': {'name': 'Arms', 'slug': 'arms'},
#        'path': '/characters/eu/tarren-mill/Landqvist-10681862',
#        'realm': {'id': 719,
#         'connectedRealmId': 300,
#         'name': 'Tarren Mill',
#         'altName': None,
#         'slug': 'tarren-mill',
#         'altSlug': 'tarren-mill',
#         'locale': 'en_GB',
#         'isConnected': True},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 11528267,
#        'persona_id': 2019174,
#        'name': 'Naowhxoxo-11528267',
#        'class': {'id': 6, 'name': 'Death Knight', 'slug': 'death-knight'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 110,
#        'spec': {'name': 'Blood', 'slug': 'blood'},
#        'path': '/characters/eu/twisting-nether/Naowhxoxo-11528267',
#        'realm': {'id': 739,
#         'connectedRealmId': 362,
#         'name': 'Twisting Nether',
#         'altName': None,
#         'slug': 'twisting-nether',
#         'altSlug': 'twisting-nether',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'tank'}],
#     'platoon': None}},
#   {'rank': 3,
#    'score': 380.2,
#    'run': {'season': 'season-7.3.0',
#     'status': 'finished',
#     'dungeon': {'id': 8079,
#      'name': 'Court of Stars',
#      'short_name': 'COS',
#      'slug': 'court-of-stars',
#      'expansion_id': 6,
#      'patch': '7.0',
#      'keystone_timer_ms': 1800999,
#      'num_bosses': 3,
#      'group_finder_activity_id': 466},
#     'keystone_run_id': 3751713,
#     'mythic_level': 24,
#     'clear_time_ms': 1774388,
#     'keystone_time_ms': 1800999,
#     'completed_at': '2017-11-19T04:26:38.000Z',
#     'num_chests': 1,
#     'time_remaining_ms': 26611,
#     'logged_run_id': None,
#     'weekly_modifiers': [{'id': 8,
#       'icon': 'spell_shadow_bloodboil',
#       'name': 'Sanguine',
#       'description': 'When slain, non-boss enemies leave behind a lingering pool of ichor that heals their allies and damages players.'},
#      {'id': 12,
#       'icon': 'ability_backstab',
#       'name': 'Grievous',
#       'description': 'Injured players suffer increasing damage over time until healed.'},
#      {'id': 10,
#       'icon': 'ability_toughness',
#       'name': 'Fortified',
#       'description': 'Non-boss enemies have 20% more health and inflict up to 30% increased damage.'}],
#     'num_modifiers_active': 3,
#     'faction': 'horde',
#     'deleted_at': None,
#     'keystone_platoon_id': None,
#     'keystone_team_id': 5327780,
#     'roster': [{'character': {'id': 28993,
#        'persona_id': 5333,
#        'name': 'Jdotb-28993',
#        'class': {'id': 11, 'name': 'Druid', 'slug': 'druid'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 110,
#        'spec': {'name': 'Restoration', 'slug': 'restoration'},
#        'path': '/characters/us/illidan/Jdotb-28993',
#        'realm': {'id': 369,
#         'connectedRealmId': 207,
#         'name': 'Illidan',
#         'altName': None,
#         'slug': 'illidan',
#         'altSlug': 'illidan',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'healer'},
#      {'character': {'id': 212772,
#        'persona_id': 44161,
#        'name': 'Marvink',
#        'class': {'id': 9, 'name': 'Warlock', 'slug': 'warlock'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 60,
#        'spec': {'name': 'Affliction', 'slug': 'affliction'},
#        'path': '/characters/us/area-52/Marvink',
#        'realm': {'id': 264,
#         'connectedRealmId': 136,
#         'name': 'Area 52',
#         'altName': None,
#         'slug': 'area-52',
#         'altSlug': 'area-52',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': False,
#       'role': 'dps'},
#      {'character': {'id': 323418,
#        'persona_id': 243088,
#        'name': 'Shakib-323418',
#        'class': {'id': 12, 'name': 'Demon Hunter', 'slug': 'demon-hunter'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 50,
#        'spec': {'name': 'Havoc', 'slug': 'havoc'},
#        'path': '/characters/us/turalyon/Shakib-323418',
#        'realm': {'id': 472,
#         'connectedRealmId': 238,
#         'name': 'Turalyon',
#         'altName': None,
#         'slug': 'turalyon',
#         'altSlug': 'turalyon',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'tank'},
#      {'character': {'id': 1037382,
#        'persona_id': 2660542,
#        'name': 'Fûryz-1037382',
#        'class': {'id': 1, 'name': 'Warrior', 'slug': 'warrior'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 50,
#        'spec': {'name': 'Arms', 'slug': 'arms'},
#        'path': '/characters/us/tichondrius/Fûryz-1037382',
#        'realm': {'id': 468,
#         'connectedRealmId': 236,
#         'name': 'Tichondrius',
#         'altName': None,
#         'slug': 'tichondrius',
#         'altSlug': 'tichondrius',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 9880279,
#        'persona_id': 41153,
#        'name': 'Mittbitt-9880279',
#        'class': {'id': 11, 'name': 'Druid', 'slug': 'druid'},
#        'race': {'id': 6,
#         'name': 'Tauren',
#         'slug': 'tauren',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 110,
#        'spec': {'name': 'Balance', 'slug': 'balance'},
#        'path': '/characters/us/stormreaver/Mittbitt-9880279',
#        'realm': {'id': 453,
#         'connectedRealmId': 234,
#         'name': 'Stormreaver',
#         'altName': None,
#         'slug': 'stormreaver',
#         'altSlug': 'stormreaver',
#         'locale': 'en_US',
#         'isConnected': False},
#        'region': {'name': 'United States & Oceania',
#         'slug': 'us',
#         'short_name': 'US'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'}],
#     'platoon': None}},
#   {'rank': 4,
#    'score': 379.9,
#    'run': {'season': 'season-7.3.0',
#     'status': 'finished',
#     'dungeon': {'id': 999998,
#      'name': 'Return to Karazhan: Lower',
#      'short_name': 'LOWR',
#      'slug': 'return-to-karazhan-lower',
#      'expansion_id': 6,
#      'patch': '7.2',
#      'keystone_timer_ms': 2520999,
#      'num_bosses': 4,
#      'group_finder_activity_id': 471},
#     'keystone_run_id': 3829885,
#     'mythic_level': 24,
#     'clear_time_ms': 2331984,
#     'keystone_time_ms': 2340999,
#     'completed_at': '2017-11-21T01:55:35.000Z',
#     'num_chests': 1,
#     'time_remaining_ms': 9015,
#     'logged_run_id': None,
#     'weekly_modifiers': [{'id': 8,
#       'icon': 'spell_shadow_bloodboil',
#       'name': 'Sanguine',
#       'description': 'When slain, non-boss enemies leave behind a lingering pool of ichor that heals their allies and damages players.'},
#      {'id': 12,
#       'icon': 'ability_backstab',
#       'name': 'Grievous',
#       'description': 'Injured players suffer increasing damage over time until healed.'},
#      {'id': 10,
#       'icon': 'ability_toughness',
#       'name': 'Fortified',
#       'description': 'Non-boss enemies have 20% more health and inflict up to 30% increased damage.'}],
#     'num_modifiers_active': 3,
#     'faction': 'horde',
#     'deleted_at': None,
#     'keystone_platoon_id': None,
#     'keystone_team_id': 6781907,
#     'roster': [{'character': {'id': 1165923,
#        'persona_id': 2669705,
#        'name': 'Miraclestep-1165923',
#        'class': {'id': 4, 'name': 'Rogue', 'slug': 'rogue'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 50,
#        'spec': {'name': 'Assassination', 'slug': 'assassination'},
#        'path': '/characters/eu/stormscale/Miraclestep-1165923',
#        'realm': {'id': 713,
#         'connectedRealmId': 357,
#         'name': 'Stormscale',
#         'altName': None,
#         'slug': 'stormscale',
#         'altSlug': 'stormscale',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 4306794,
#        'persona_id': 3646890,
#        'name': 'Tasnaran-4306794',
#        'class': {'id': 11, 'name': 'Druid', 'slug': 'druid'},
#        'race': {'id': 6,
#         'name': 'Tauren',
#         'slug': 'tauren',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 50,
#        'spec': {'name': 'Restoration', 'slug': 'restoration'},
#        'path': '/characters/eu/twisting-nether/Tasnaran-4306794',
#        'realm': {'id': 739,
#         'connectedRealmId': 362,
#         'name': 'Twisting Nether',
#         'altName': None,
#         'slug': 'twisting-nether',
#         'altSlug': 'twisting-nether',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'healer'},
#      {'character': {'id': 7261250,
#        'persona_id': 1818682,
#        'name': 'Deepshades-7261250',
#        'class': {'id': 9, 'name': 'Warlock', 'slug': 'warlock'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 60,
#        'spec': {'name': 'Affliction', 'slug': 'affliction'},
#        'path': '/characters/eu/tarren-mill/Deepshades-7261250',
#        'realm': {'id': 719,
#         'connectedRealmId': 300,
#         'name': 'Tarren Mill',
#         'altName': None,
#         'slug': 'tarren-mill',
#         'altSlug': 'tarren-mill',
#         'locale': 'en_GB',
#         'isConnected': True},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 8427780,
#        'persona_id': 2020384,
#        'name': 'Herudra',
#        'class': {'id': 1, 'name': 'Warrior', 'slug': 'warrior'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 70,
#        'spec': {'name': 'Arms', 'slug': 'arms'},
#        'path': '/characters/eu/draenor/Herudra',
#        'realm': {'id': 579,
#         'connectedRealmId': 308,
#         'name': 'Draenor',
#         'altName': None,
#         'slug': 'draenor',
#         'altSlug': 'draenor',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': False,
#       'role': 'dps'},
#      {'character': {'id': 11528267,
#        'persona_id': 2019174,
#        'name': 'Naowhxoxo-11528267',
#        'class': {'id': 6, 'name': 'Death Knight', 'slug': 'death-knight'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 110,
#        'spec': {'name': 'Blood', 'slug': 'blood'},
#        'path': '/characters/eu/twisting-nether/Naowhxoxo-11528267',
#        'realm': {'id': 739,
#         'connectedRealmId': 362,
#         'name': 'Twisting Nether',
#         'altName': None,
#         'slug': 'twisting-nether',
#         'altSlug': 'twisting-nether',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'tank'}],
#     'platoon': None}},
#   {'rank': 5,
#    'score': 379.8,
#    'run': {'season': 'season-7.3.0',
#     'status': 'finished',
#     'dungeon': {'id': 8527,
#      'name': 'Cathedral of Eternal Night',
#      'short_name': 'COEN',
#      'slug': 'cathedral-of-eternal-night',
#      'expansion_id': 6,
#      'patch': '7.2',
#      'keystone_timer_ms': 2100999,
#      'num_bosses': 4,
#      'group_finder_activity_id': 476},
#     'keystone_run_id': 3689362,
#     'mythic_level': 24,
#     'clear_time_ms': 2099171,
#     'keystone_time_ms': 2100999,
#     'completed_at': '2017-11-17T22:58:05.000Z',
#     'num_chests': 1,
#     'time_remaining_ms': 1828,
#     'logged_run_id': None,
#     'weekly_modifiers': [{'id': 8,
#       'icon': 'spell_shadow_bloodboil',
#       'name': 'Sanguine',
#       'description': 'When slain, non-boss enemies leave behind a lingering pool of ichor that heals their allies and damages players.'},
#      {'id': 12,
#       'icon': 'ability_backstab',
#       'name': 'Grievous',
#       'description': 'Injured players suffer increasing damage over time until healed.'},
#      {'id': 10,
#       'icon': 'ability_toughness',
#       'name': 'Fortified',
#       'description': 'Non-boss enemies have 20% more health and inflict up to 30% increased damage.'}],
#     'num_modifiers_active': 3,
#     'faction': 'horde',
#     'deleted_at': None,
#     'keystone_platoon_id': None,
#     'keystone_team_id': 6649513,
#     'roster': [{'character': {'id': 1165923,
#        'persona_id': 2669705,
#        'name': 'Miraclestep-1165923',
#        'class': {'id': 4, 'name': 'Rogue', 'slug': 'rogue'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 50,
#        'spec': {'name': 'Assassination', 'slug': 'assassination'},
#        'path': '/characters/eu/stormscale/Miraclestep-1165923',
#        'realm': {'id': 713,
#         'connectedRealmId': 357,
#         'name': 'Stormscale',
#         'altName': None,
#         'slug': 'stormscale',
#         'altSlug': 'stormscale',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 4306794,
#        'persona_id': 3646890,
#        'name': 'Tasnaran-4306794',
#        'class': {'id': 11, 'name': 'Druid', 'slug': 'druid'},
#        'race': {'id': 6,
#         'name': 'Tauren',
#         'slug': 'tauren',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 50,
#        'spec': {'name': 'Restoration', 'slug': 'restoration'},
#        'path': '/characters/eu/twisting-nether/Tasnaran-4306794',
#        'realm': {'id': 739,
#         'connectedRealmId': 362,
#         'name': 'Twisting Nether',
#         'altName': None,
#         'slug': 'twisting-nether',
#         'altSlug': 'twisting-nether',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'healer'},
#      {'character': {'id': 7261250,
#        'persona_id': 1818682,
#        'name': 'Deepshades-7261250',
#        'class': {'id': 9, 'name': 'Warlock', 'slug': 'warlock'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 60,
#        'spec': {'name': 'Affliction', 'slug': 'affliction'},
#        'path': '/characters/eu/tarren-mill/Deepshades-7261250',
#        'realm': {'id': 719,
#         'connectedRealmId': 300,
#         'name': 'Tarren Mill',
#         'altName': None,
#         'slug': 'tarren-mill',
#         'altSlug': 'tarren-mill',
#         'locale': 'en_GB',
#         'isConnected': True},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 10681862,
#        'persona_id': 18349770,
#        'name': 'Landqvist-10681862',
#        'class': {'id': 1, 'name': 'Warrior', 'slug': 'warrior'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 50,
#        'spec': {'name': 'Arms', 'slug': 'arms'},
#        'path': '/characters/eu/tarren-mill/Landqvist-10681862',
#        'realm': {'id': 719,
#         'connectedRealmId': 300,
#         'name': 'Tarren Mill',
#         'altName': None,
#         'slug': 'tarren-mill',
#         'altSlug': 'tarren-mill',
#         'locale': 'en_GB',
#         'isConnected': True},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 11528267,
#        'persona_id': 2019174,
#        'name': 'Naowhxoxo-11528267',
#        'class': {'id': 6, 'name': 'Death Knight', 'slug': 'death-knight'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 110,
#        'spec': {'name': 'Blood', 'slug': 'blood'},
#        'path': '/characters/eu/twisting-nether/Naowhxoxo-11528267',
#        'realm': {'id': 739,
#         'connectedRealmId': 362,
#         'name': 'Twisting Nether',
#         'altName': None,
#         'slug': 'twisting-nether',
#         'altSlug': 'twisting-nether',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'tank'}],
#     'platoon': None}},
#   {'rank': 6,
#    'score': 358.5,
#    'run': {'season': 'season-7.3.0',
#     'status': 'finished',
#     'dungeon': {'id': 999999,
#      'name': 'Return to Karazhan: Upper',
#      'short_name': 'UPPR',
#      'slug': 'return-to-karazhan-upper',
#      'expansion_id': 6,
#      'patch': '7.2',
#      'keystone_timer_ms': 2100999,
#      'num_bosses': 4,
#      'group_finder_activity_id': 471},
#     'keystone_run_id': 3720008,
#     'mythic_level': 23,
#     'clear_time_ms': 1509071,
#     'keystone_time_ms': 2100999,
#     'completed_at': '2017-11-18T15:47:30.000Z',
#     'num_chests': 2,
#     'time_remaining_ms': 591928,
#     'logged_run_id': None,
#     'weekly_modifiers': [{'id': 8,
#       'icon': 'spell_shadow_bloodboil',
#       'name': 'Sanguine',
#       'description': 'When slain, non-boss enemies leave behind a lingering pool of ichor that heals their allies and damages players.'},
#      {'id': 12,
#       'icon': 'ability_backstab',
#       'name': 'Grievous',
#       'description': 'Injured players suffer increasing damage over time until healed.'},
#      {'id': 10,
#       'icon': 'ability_toughness',
#       'name': 'Fortified',
#       'description': 'Non-boss enemies have 20% more health and inflict up to 30% increased damage.'}],
#     'num_modifiers_active': 3,
#     'faction': 'horde',
#     'deleted_at': None,
#     'keystone_platoon_id': None,
#     'keystone_team_id': 6678791,
#     'roster': [{'character': {'id': 323366,
#        'persona_id': 243047,
#        'name': 'Killertomaté-323366',
#        'class': {'id': 9, 'name': 'Warlock', 'slug': 'warlock'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 50,
#        'spec': {'name': 'Destruction', 'slug': 'destruction'},
#        'path': '/characters/eu/thrall/Killertomaté-323366',
#        'realm': {'id': 730,
#         'connectedRealmId': 359,
#         'name': 'Thrall',
#         'altName': None,
#         'slug': 'thrall',
#         'altSlug': 'thrall',
#         'locale': 'de_DE',
#         'isConnected': True},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 1165923,
#        'persona_id': 2669705,
#        'name': 'Miraclestep-1165923',
#        'class': {'id': 4, 'name': 'Rogue', 'slug': 'rogue'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 50,
#        'spec': {'name': 'Assassination', 'slug': 'assassination'},
#        'path': '/characters/eu/stormscale/Miraclestep-1165923',
#        'realm': {'id': 713,
#         'connectedRealmId': 357,
#         'name': 'Stormscale',
#         'altName': None,
#         'slug': 'stormscale',
#         'altSlug': 'stormscale',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 8427780,
#        'persona_id': 2020384,
#        'name': 'Herudra',
#        'class': {'id': 1, 'name': 'Warrior', 'slug': 'warrior'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 70,
#        'spec': {'name': 'Arms', 'slug': 'arms'},
#        'path': '/characters/eu/draenor/Herudra',
#        'realm': {'id': 579,
#         'connectedRealmId': 308,
#         'name': 'Draenor',
#         'altName': None,
#         'slug': 'draenor',
#         'altSlug': 'draenor',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': False,
#       'role': 'dps'},
#      {'character': {'id': 9729302,
#        'persona_id': 988646,
#        'name': 'Imbanane-9729302',
#        'class': {'id': 2, 'name': 'Paladin', 'slug': 'paladin'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 110,
#        'spec': {'name': 'Holy', 'slug': 'holy'},
#        'path': '/characters/eu/thrall/Imbanane-9729302',
#        'realm': {'id': 730,
#         'connectedRealmId': 359,
#         'name': 'Thrall',
#         'altName': None,
#         'slug': 'thrall',
#         'altSlug': 'thrall',
#         'locale': 'de_DE',
#         'isConnected': True},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'healer'},
#      {'character': {'id': 11528267,
#        'persona_id': 2019174,
#        'name': 'Naowhxoxo-11528267',
#        'class': {'id': 6, 'name': 'Death Knight', 'slug': 'death-knight'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 110,
#        'spec': {'name': 'Blood', 'slug': 'blood'},
#        'path': '/characters/eu/twisting-nether/Naowhxoxo-11528267',
#        'realm': {'id': 739,
#         'connectedRealmId': 362,
#         'name': 'Twisting Nether',
#         'altName': None,
#         'slug': 'twisting-nether',
#         'altSlug': 'twisting-nether',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'tank'}],
#     'platoon': None}},
#   {'rank': 7,
#    'score': 356.4,
#    'run': {'season': 'season-7.3.0',
#     'status': 'finished',
#     'dungeon': {'id': 999999,
#      'name': 'Return to Karazhan: Upper',
#      'short_name': 'UPPR',
#      'slug': 'return-to-karazhan-upper',
#      'expansion_id': 6,
#      'patch': '7.2',
#      'keystone_timer_ms': 2100999,
#      'num_bosses': 4,
#      'group_finder_activity_id': 471},
#     'keystone_run_id': 3743455,
#     'mythic_level': 23,
#     'clear_time_ms': 1658545,
#     'keystone_time_ms': 2100999,
#     'completed_at': '2017-11-18T23:21:25.000Z',
#     'num_chests': 2,
#     'time_remaining_ms': 442454,
#     'logged_run_id': None,
#     'weekly_modifiers': [{'id': 8,
#       'icon': 'spell_shadow_bloodboil',
#       'name': 'Sanguine',
#       'description': 'When slain, non-boss enemies leave behind a lingering pool of ichor that heals their allies and damages players.'},
#      {'id': 12,
#       'icon': 'ability_backstab',
#       'name': 'Grievous',
#       'description': 'Injured players suffer increasing damage over time until healed.'},
#      {'id': 10,
#       'icon': 'ability_toughness',
#       'name': 'Fortified',
#       'description': 'Non-boss enemies have 20% more health and inflict up to 30% increased damage.'}],
#     'num_modifiers_active': 3,
#     'faction': 'horde',
#     'deleted_at': None,
#     'keystone_platoon_id': None,
#     'keystone_team_id': 6659685,
#     'roster': [{'character': {'id': 1165923,
#        'persona_id': 2669705,
#        'name': 'Miraclestep-1165923',
#        'class': {'id': 4, 'name': 'Rogue', 'slug': 'rogue'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 50,
#        'spec': {'name': 'Assassination', 'slug': 'assassination'},
#        'path': '/characters/eu/stormscale/Miraclestep-1165923',
#        'realm': {'id': 713,
#         'connectedRealmId': 357,
#         'name': 'Stormscale',
#         'altName': None,
#         'slug': 'stormscale',
#         'altSlug': 'stormscale',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 7261250,
#        'persona_id': 1818682,
#        'name': 'Deepshades-7261250',
#        'class': {'id': 9, 'name': 'Warlock', 'slug': 'warlock'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 60,
#        'spec': {'name': 'Affliction', 'slug': 'affliction'},
#        'path': '/characters/eu/tarren-mill/Deepshades-7261250',
#        'realm': {'id': 719,
#         'connectedRealmId': 300,
#         'name': 'Tarren Mill',
#         'altName': None,
#         'slug': 'tarren-mill',
#         'altSlug': 'tarren-mill',
#         'locale': 'en_GB',
#         'isConnected': True},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 8427780,
#        'persona_id': 2020384,
#        'name': 'Herudra',
#        'class': {'id': 1, 'name': 'Warrior', 'slug': 'warrior'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 70,
#        'spec': {'name': 'Arms', 'slug': 'arms'},
#        'path': '/characters/eu/draenor/Herudra',
#        'realm': {'id': 579,
#         'connectedRealmId': 308,
#         'name': 'Draenor',
#         'altName': None,
#         'slug': 'draenor',
#         'altSlug': 'draenor',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': False,
#       'role': 'dps'},
#      {'character': {'id': 9729302,
#        'persona_id': 988646,
#        'name': 'Imbanane-9729302',
#        'class': {'id': 2, 'name': 'Paladin', 'slug': 'paladin'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 110,
#        'spec': {'name': 'Holy', 'slug': 'holy'},
#        'path': '/characters/eu/thrall/Imbanane-9729302',
#        'realm': {'id': 730,
#         'connectedRealmId': 359,
#         'name': 'Thrall',
#         'altName': None,
#         'slug': 'thrall',
#         'altSlug': 'thrall',
#         'locale': 'de_DE',
#         'isConnected': True},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'healer'},
#      {'character': {'id': 11528267,
#        'persona_id': 2019174,
#        'name': 'Naowhxoxo-11528267',
#        'class': {'id': 6, 'name': 'Death Knight', 'slug': 'death-knight'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 110,
#        'spec': {'name': 'Blood', 'slug': 'blood'},
#        'path': '/characters/eu/twisting-nether/Naowhxoxo-11528267',
#        'realm': {'id': 739,
#         'connectedRealmId': 362,
#         'name': 'Twisting Nether',
#         'altName': None,
#         'slug': 'twisting-nether',
#         'altSlug': 'twisting-nether',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'tank'}],
#     'platoon': None}},
#   {'rank': 8,
#    'score': 356.3,
#    'run': {'season': 'season-7.3.0',
#     'status': 'finished',
#     'dungeon': {'id': 999998,
#      'name': 'Return to Karazhan: Lower',
#      'short_name': 'LOWR',
#      'slug': 'return-to-karazhan-lower',
#      'expansion_id': 6,
#      'patch': '7.2',
#      'keystone_timer_ms': 2520999,
#      'num_bosses': 4,
#      'group_finder_activity_id': 471},
#     'keystone_run_id': 3687213,
#     'mythic_level': 23,
#     'clear_time_ms': 1856368,
#     'keystone_time_ms': 2340999,
#     'completed_at': '2017-11-17T22:21:58.000Z',
#     'num_chests': 2,
#     'time_remaining_ms': 484631,
#     'logged_run_id': None,
#     'weekly_modifiers': [{'id': 8,
#       'icon': 'spell_shadow_bloodboil',
#       'name': 'Sanguine',
#       'description': 'When slain, non-boss enemies leave behind a lingering pool of ichor that heals their allies and damages players.'},
#      {'id': 12,
#       'icon': 'ability_backstab',
#       'name': 'Grievous',
#       'description': 'Injured players suffer increasing damage over time until healed.'},
#      {'id': 10,
#       'icon': 'ability_toughness',
#       'name': 'Fortified',
#       'description': 'Non-boss enemies have 20% more health and inflict up to 30% increased damage.'}],
#     'num_modifiers_active': 3,
#     'faction': 'horde',
#     'deleted_at': None,
#     'keystone_platoon_id': None,
#     'keystone_team_id': 6531360,
#     'roster': [{'character': {'id': 3859964,
#        'persona_id': 3616040,
#        'name': 'Ciralliou-3859964',
#        'class': {'id': 2, 'name': 'Paladin', 'slug': 'paladin'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 110,
#        'spec': {'name': 'Holy', 'slug': 'holy'},
#        'path': '/characters/eu/kazzak/Ciralliou-3859964',
#        'realm': {'id': 631,
#         'connectedRealmId': 336,
#         'name': 'Kazzak',
#         'altName': None,
#         'slug': 'kazzak',
#         'altSlug': 'kazzak',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'healer'},
#      {'character': {'id': 3943414,
#        'persona_id': 1096776,
#        'name': 'Dorullkjell-3943414',
#        'class': {'id': 11, 'name': 'Druid', 'slug': 'druid'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 50,
#        'spec': {'name': 'Balance', 'slug': 'balance'},
#        'path': '/characters/eu/draenor/Dorullkjell-3943414',
#        'realm': {'id': 579,
#         'connectedRealmId': 308,
#         'name': 'Draenor',
#         'altName': None,
#         'slug': 'draenor',
#         'altSlug': 'draenor',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 10846791,
#        'persona_id': 75446,
#        'name': 'Divinefield-10846791',
#        'class': {'id': 2, 'name': 'Paladin', 'slug': 'paladin'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 50,
#        'spec': {'name': 'Protection', 'slug': 'protection'},
#        'path': '/characters/eu/kazzak/Divinefield-10846791',
#        'realm': {'id': 631,
#         'connectedRealmId': 336,
#         'name': 'Kazzak',
#         'altName': None,
#         'slug': 'kazzak',
#         'altSlug': 'kazzak',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'tank'},
#      {'character': {'id': 11295549,
#        'persona_id': 368800,
#        'name': 'Fanatìk-11295549',
#        'class': {'id': 1, 'name': 'Warrior', 'slug': 'warrior'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 60,
#        'spec': {'name': 'Fury', 'slug': 'fury'},
#        'path': '/characters/eu/kazzak/Fanatìk-11295549',
#        'realm': {'id': 631,
#         'connectedRealmId': 336,
#         'name': 'Kazzak',
#         'altName': None,
#         'slug': 'kazzak',
#         'altSlug': 'kazzak',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 11351967,
#        'persona_id': 3855218,
#        'name': 'Blakexo-11351967',
#        'class': {'id': 9, 'name': 'Warlock', 'slug': 'warlock'},
#        'race': {'id': 5,
#         'name': 'Undead',
#         'slug': 'undead',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 110,
#        'spec': {'name': 'Affliction', 'slug': 'affliction'},
#        'path': '/characters/eu/kazzak/Blakexo-11351967',
#        'realm': {'id': 631,
#         'connectedRealmId': 336,
#         'name': 'Kazzak',
#         'altName': None,
#         'slug': 'kazzak',
#         'altSlug': 'kazzak',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'}],
#     'platoon': None}},
#   {'rank': 9,
#    'score': 351,
#    'run': {'season': 'season-7.3.0',
#     'status': 'finished',
#     'dungeon': {'id': 999999,
#      'name': 'Return to Karazhan: Upper',
#      'short_name': 'UPPR',
#      'slug': 'return-to-karazhan-upper',
#      'expansion_id': 6,
#      'patch': '7.2',
#      'keystone_timer_ms': 2100999,
#      'num_bosses': 4,
#      'group_finder_activity_id': 471},
#     'keystone_run_id': 3820581,
#     'mythic_level': 23,
#     'clear_time_ms': 1685575,
#     'keystone_time_ms': 2100999,
#     'completed_at': '2017-11-20T21:22:09.000Z',
#     'num_chests': 1,
#     'time_remaining_ms': 415424,
#     'logged_run_id': None,
#     'weekly_modifiers': [{'id': 8,
#       'icon': 'spell_shadow_bloodboil',
#       'name': 'Sanguine',
#       'description': 'When slain, non-boss enemies leave behind a lingering pool of ichor that heals their allies and damages players.'},
#      {'id': 12,
#       'icon': 'ability_backstab',
#       'name': 'Grievous',
#       'description': 'Injured players suffer increasing damage over time until healed.'},
#      {'id': 10,
#       'icon': 'ability_toughness',
#       'name': 'Fortified',
#       'description': 'Non-boss enemies have 20% more health and inflict up to 30% increased damage.'}],
#     'num_modifiers_active': 3,
#     'faction': 'horde',
#     'deleted_at': None,
#     'keystone_platoon_id': None,
#     'keystone_team_id': 6772396,
#     'roster': [{'character': {'id': 28993,
#        'persona_id': 5333,
#        'name': 'Jdotb-28993',
#        'class': {'id': 11, 'name': 'Druid', 'slug': 'druid'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 110,
# ...
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 50,
#        'spec': {'name': 'Assassination', 'slug': 'assassination'},
#        'path': '/characters/eu/stormscale/Miraclestep-1165923',
#        'realm': {'id': 713,
#         'connectedRealmId': 357,
#         'name': 'Stormscale',
#         'altName': None,
#         'slug': 'stormscale',
#         'altSlug': 'stormscale',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 7261250,
#        'persona_id': 1818682,
#        'name': 'Deepshades-7261250',
#        'class': {'id': 9, 'name': 'Warlock', 'slug': 'warlock'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 60,
#        'spec': {'name': 'Affliction', 'slug': 'affliction'},
#        'path': '/characters/eu/tarren-mill/Deepshades-7261250',
#        'realm': {'id': 719,
#         'connectedRealmId': 300,
#         'name': 'Tarren Mill',
#         'altName': None,
#         'slug': 'tarren-mill',
#         'altSlug': 'tarren-mill',
#         'locale': 'en_GB',
#         'isConnected': True},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 8427780,
#        'persona_id': 2020384,
#        'name': 'Herudra',
#        'class': {'id': 1, 'name': 'Warrior', 'slug': 'warrior'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 70,
#        'spec': {'name': 'Arms', 'slug': 'arms'},
#        'path': '/characters/eu/draenor/Herudra',
#        'realm': {'id': 579,
#         'connectedRealmId': 308,
#         'name': 'Draenor',
#         'altName': None,
#         'slug': 'draenor',
#         'altSlug': 'draenor',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': False,
#       'role': 'dps'},
#      {'character': {'id': 9729302,
#        'persona_id': 988646,
#        'name': 'Imbanane-9729302',
#        'class': {'id': 2, 'name': 'Paladin', 'slug': 'paladin'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 110,
#        'spec': {'name': 'Holy', 'slug': 'holy'},
#        'path': '/characters/eu/thrall/Imbanane-9729302',
#        'realm': {'id': 730,
#         'connectedRealmId': 359,
#         'name': 'Thrall',
#         'altName': None,
#         'slug': 'thrall',
#         'altSlug': 'thrall',
#         'locale': 'de_DE',
#         'isConnected': True},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'healer'},
#      {'character': {'id': 11528267,
#        'persona_id': 2019174,
#        'name': 'Naowhxoxo-11528267',
#        'class': {'id': 6, 'name': 'Death Knight', 'slug': 'death-knight'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 110,
#        'spec': {'name': 'Blood', 'slug': 'blood'},
#        'path': '/characters/eu/twisting-nether/Naowhxoxo-11528267',
#        'realm': {'id': 739,
#         'connectedRealmId': 362,
#         'name': 'Twisting Nether',
#         'altName': None,
#         'slug': 'twisting-nether',
#         'altSlug': 'twisting-nether',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'tank'}],
#     'platoon': None}},
#   {'rank': 19,
#    'score': 347.7,
#    'run': {'season': 'season-7.3.0',
#     'status': 'finished',
#     'dungeon': {'id': 7673,
#      'name': 'Darkheart Thicket',
#      'short_name': 'DHT',
#      'slug': 'darkheart-thicket',
#      'expansion_id': 6,
#      'patch': '7.0',
#      'keystone_timer_ms': 1800999,
#      'num_bosses': 4,
#      'group_finder_activity_id': 460},
#     'keystone_run_id': 3777160,
#     'mythic_level': 23,
#     'clear_time_ms': 1646082,
#     'keystone_time_ms': 1800999,
#     'completed_at': '2017-11-19T18:11:06.000Z',
#     'num_chests': 1,
#     'time_remaining_ms': 154917,
#     'logged_run_id': None,
#     'weekly_modifiers': [{'id': 8,
#       'icon': 'spell_shadow_bloodboil',
#       'name': 'Sanguine',
#       'description': 'When slain, non-boss enemies leave behind a lingering pool of ichor that heals their allies and damages players.'},
#      {'id': 12,
#       'icon': 'ability_backstab',
#       'name': 'Grievous',
#       'description': 'Injured players suffer increasing damage over time until healed.'},
#      {'id': 10,
#       'icon': 'ability_toughness',
#       'name': 'Fortified',
#       'description': 'Non-boss enemies have 20% more health and inflict up to 30% increased damage.'}],
#     'num_modifiers_active': 3,
#     'faction': 'horde',
#     'deleted_at': None,
#     'keystone_platoon_id': None,
#     'keystone_team_id': 6732338,
#     'roster': [{'character': {'id': 323366,
#        'persona_id': 243047,
#        'name': 'Killertomaté-323366',
#        'class': {'id': 9, 'name': 'Warlock', 'slug': 'warlock'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 50,
#        'spec': {'name': 'Destruction', 'slug': 'destruction'},
#        'path': '/characters/eu/thrall/Killertomaté-323366',
#        'realm': {'id': 730,
#         'connectedRealmId': 359,
#         'name': 'Thrall',
#         'altName': None,
#         'slug': 'thrall',
#         'altSlug': 'thrall',
#         'locale': 'de_DE',
#         'isConnected': True},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 1165923,
#        'persona_id': 2669705,
#        'name': 'Miraclestep-1165923',
#        'class': {'id': 4, 'name': 'Rogue', 'slug': 'rogue'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 50,
#        'spec': {'name': 'Assassination', 'slug': 'assassination'},
#        'path': '/characters/eu/stormscale/Miraclestep-1165923',
#        'realm': {'id': 713,
#         'connectedRealmId': 357,
#         'name': 'Stormscale',
#         'altName': None,
#         'slug': 'stormscale',
#         'altSlug': 'stormscale',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 4306794,
#        'persona_id': 3646890,
#        'name': 'Tasnaran-4306794',
#        'class': {'id': 11, 'name': 'Druid', 'slug': 'druid'},
#        'race': {'id': 6,
#         'name': 'Tauren',
#         'slug': 'tauren',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 50,
#        'spec': {'name': 'Restoration', 'slug': 'restoration'},
#        'path': '/characters/eu/twisting-nether/Tasnaran-4306794',
#        'realm': {'id': 739,
#         'connectedRealmId': 362,
#         'name': 'Twisting Nether',
#         'altName': None,
#         'slug': 'twisting-nether',
#         'altSlug': 'twisting-nether',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'healer'},
#      {'character': {'id': 8427780,
#        'persona_id': 2020384,
#        'name': 'Herudra',
#        'class': {'id': 1, 'name': 'Warrior', 'slug': 'warrior'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 70,
#        'spec': {'name': 'Arms', 'slug': 'arms'},
#        'path': '/characters/eu/draenor/Herudra',
#        'realm': {'id': 579,
#         'connectedRealmId': 308,
#         'name': 'Draenor',
#         'altName': None,
#         'slug': 'draenor',
#         'altSlug': 'draenor',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': False,
#       'role': 'dps'},
#      {'character': {'id': 11528267,
#        'persona_id': 2019174,
#        'name': 'Naowhxoxo-11528267',
#        'class': {'id': 6, 'name': 'Death Knight', 'slug': 'death-knight'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 110,
#        'spec': {'name': 'Blood', 'slug': 'blood'},
#        'path': '/characters/eu/twisting-nether/Naowhxoxo-11528267',
#        'realm': {'id': 739,
#         'connectedRealmId': 362,
#         'name': 'Twisting Nether',
#         'altName': None,
#         'slug': 'twisting-nether',
#         'altSlug': 'twisting-nether',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'tank'}],
#     'platoon': None}},
#   {'rank': 20,
#    'score': 347.7,
#    'run': {'season': 'season-7.3.0',
#     'status': 'finished',
#     'dungeon': {'id': 999998,
#      'name': 'Return to Karazhan: Lower',
#      'short_name': 'LOWR',
#      'slug': 'return-to-karazhan-lower',
#      'expansion_id': 6,
#      'patch': '7.2',
#      'keystone_timer_ms': 2520999,
#      'num_bosses': 4,
#      'group_finder_activity_id': 471},
#     'keystone_run_id': 3749744,
#     'mythic_level': 23,
#     'clear_time_ms': 2144105,
#     'keystone_time_ms': 2340999,
#     'completed_at': '2017-11-19T02:05:49.000Z',
#     'num_chests': 1,
#     'time_remaining_ms': 196894,
#     'logged_run_id': None,
#     'weekly_modifiers': [{'id': 8,
#       'icon': 'spell_shadow_bloodboil',
#       'name': 'Sanguine',
#       'description': 'When slain, non-boss enemies leave behind a lingering pool of ichor that heals their allies and damages players.'},
#      {'id': 12,
#       'icon': 'ability_backstab',
#       'name': 'Grievous',
#       'description': 'Injured players suffer increasing damage over time until healed.'},
#      {'id': 10,
#       'icon': 'ability_toughness',
#       'name': 'Fortified',
#       'description': 'Non-boss enemies have 20% more health and inflict up to 30% increased damage.'}],
#     'num_modifiers_active': 3,
#     'faction': 'horde',
#     'deleted_at': None,
#     'keystone_platoon_id': None,
#     'keystone_team_id': 6708942,
#     'roster': [{'character': {'id': 1097711,
#        'persona_id': 2347271,
#        'name': 'Subshammy-1097711',
#        'class': {'id': 7, 'name': 'Shaman', 'slug': 'shaman'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 110,
#        'spec': {'name': 'Elemental', 'slug': 'elemental'},
#        'path': '/characters/eu/draenor/Subshammy-1097711',
#        'realm': {'id': 579,
#         'connectedRealmId': 308,
#         'name': 'Draenor',
#         'altName': None,
#         'slug': 'draenor',
#         'altSlug': 'draenor',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 1165923,
#        'persona_id': 2669705,
#        'name': 'Miraclestep-1165923',
#        'class': {'id': 4, 'name': 'Rogue', 'slug': 'rogue'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 50,
#        'spec': {'name': 'Assassination', 'slug': 'assassination'},
#        'path': '/characters/eu/stormscale/Miraclestep-1165923',
#        'realm': {'id': 713,
#         'connectedRealmId': 357,
#         'name': 'Stormscale',
#         'altName': None,
#         'slug': 'stormscale',
#         'altSlug': 'stormscale',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 7261250,
#        'persona_id': 1818682,
#        'name': 'Deepshades-7261250',
#        'class': {'id': 9, 'name': 'Warlock', 'slug': 'warlock'},
#        'race': {'id': 8, 'name': 'Troll', 'slug': 'troll', 'faction': 'horde'},
#        'faction': 'horde',
#        'level': 60,
#        'spec': {'name': 'Affliction', 'slug': 'affliction'},
#        'path': '/characters/eu/tarren-mill/Deepshades-7261250',
#        'realm': {'id': 719,
#         'connectedRealmId': 300,
#         'name': 'Tarren Mill',
#         'altName': None,
#         'slug': 'tarren-mill',
#         'altSlug': 'tarren-mill',
#         'locale': 'en_GB',
#         'isConnected': True},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'dps'},
#      {'character': {'id': 9729302,
#        'persona_id': 988646,
#        'name': 'Imbanane-9729302',
#        'class': {'id': 2, 'name': 'Paladin', 'slug': 'paladin'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 110,
#        'spec': {'name': 'Holy', 'slug': 'holy'},
#        'path': '/characters/eu/thrall/Imbanane-9729302',
#        'realm': {'id': 730,
#         'connectedRealmId': 359,
#         'name': 'Thrall',
#         'altName': None,
#         'slug': 'thrall',
#         'altSlug': 'thrall',
#         'locale': 'de_DE',
#         'isConnected': True},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'healer'},
#      {'character': {'id': 11528267,
#        'persona_id': 2019174,
#        'name': 'Naowhxoxo-11528267',
#        'class': {'id': 6, 'name': 'Death Knight', 'slug': 'death-knight'},
#        'race': {'id': 10,
#         'name': 'Blood Elf',
#         'slug': 'blood-elf',
#         'faction': 'horde'},
#        'faction': 'horde',
#        'level': 110,
#        'spec': {'name': 'Blood', 'slug': 'blood'},
#        'path': '/characters/eu/twisting-nether/Naowhxoxo-11528267',
#        'realm': {'id': 739,
#         'connectedRealmId': 362,
#         'name': 'Twisting Nether',
#         'altName': None,
#         'slug': 'twisting-nether',
#         'altSlug': 'twisting-nether',
#         'locale': 'en_GB',
#         'isConnected': False},
#        'region': {'name': 'Europe', 'slug': 'eu', 'short_name': 'EU'},
#        'stream': None,
#        'recruitmentProfiles': []},
#       'oldCharacter': None,
#       'isTransfer': True,
#       'role': 'tank'}],
#     'platoon': None}}],
#  'leaderboard_url': 'https://raider.io/mythic-plus-rankings/season-7.3.0/all/world/leaderboards-strict',
#  'params': {'season': 'season-7.3.0',
#   'region': 'world',
#   'dungeon': 'all',
#   'page': 0}}

# %% [markdown]
# ## Extracting the characters parameters (role, name, class)

# %%
#testing a loop that extracts a dataframe in which each line is a player, starting with the first run of the first page

results = []

results.append(requests.get(f'https://raider.io/api/v1/mythic-plus/runs?season=season-7.3.0&region=world&dungeon=all&page=0').json())

pd.json_normalize(results[0]['rankings'][0]['run']['roster'])
# Out:
#   oldCharacter  isTransfer    role  character.id  character.persona_id  \
# 0         None        True     dps          1744                   508
# 1         None        True    tank       1282089               2678248
# 2         None       False     dps       9311198               2110136
# 3         None        True     dps       9545803                355504
# 4         None        True  healer      10279382                173963
#
#       character.name  character.class.id character.class.name  \
# 0     Imfiredup-1744                   8                 Mage
# 1        Zqs-1282089                  10                 Monk
# 2        Wafflesauce                  11                Druid
# 3  Níghtfall-9545803                   9              Warlock
# 4     Maset-10279382                   2              Paladin
#
#   character.class.slug  character.race.id  ... character.realm.altName  \
# 0                 mage                  8  ...                    None
# 1                 monk                 10  ...                    None
# 2                druid                  6  ...                    None
# 3              warlock                  8  ...                    None
# 4              paladin                 10  ...                    None
#
#   character.realm.slug character.realm.altSlug character.realm.locale  \
# 0              illidan                 illidan                  en_US
# 1          tichondrius             tichondrius                  en_US
# 2          tichondrius             tichondrius                  en_US
# 3          tichondrius             tichondrius                  en_US
# 4               thrall                  thrall                  en_US
#
#    character.realm.isConnected    character.region.name character.region.slug  \
# 0                        False  United States & Oceania                    us
# 1                        False  United States & Oceania                    us
# 2                        False  United States & Oceania                    us
# 3                        False  United States & Oceania                    us
# 4                        False  United States & Oceania                    us
#
#   character.region.short_name  character.stream  character.recruitmentProfiles
# 0                          US              None                             []
# 1                          US              None                             []
# 2                          US              None                             []
# 3                          US              None                             []
# 4                          US              None                             []
#
# [5 rows x 31 columns]

# %%
#loop to extract all the names of the players from the first 100 pages of a specific season, an error was found on page 13,
#since there was a run with only 3 players registered

results = []
seasons = ['season-7.2.0']

for season in seasons:
    for spage in range(13):
        results.append(requests.get(f'https://raider.io/api/v1/mythic-plus/runs?season={season}&region=world&dungeon=all&page={spage}').json())


characters = []

for page in range(13):
    for run in range(8):
        for char in range(5):
            characters.append(results[page]['rankings'][run]['run']['roster'][char])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [4], in <cell line: 14>()
#      15 for run in range(8):
#      16     for char in range(5):
# ---> 17         characters.append(results[page]['rankings'][run]['run']['roster'][char])
#
# IndexError: list index out of range

# %%
#the solution was to parameterize the values so that it didn't matter if the number of players registered in a run was 5 or not.
num_of_pages = len(results)
characters = []

for page in range(num_of_pages):
    num_of_run = len(results[page]['rankings'])
    for run in range(num_of_run):
        num_of_char = len(results[page]['rankings'][run]['run']['roster'])
        for char in range(num_of_char):
            characters.append(results[page]['rankings'][run]['run']['roster'][char])

# %% [markdown]
# ## Creating a dataframe for the results

# %%
df = pd.json_normalize(characters)
df

# %% [markdown]
# ## Dataframe cleaning

# %%
df_drop = df.drop(df.columns.difference(['role', 'season', 'character.class.name', 'character.spec.name', 'character.region.name']), 1)

# %%
df_drop

# %%
df_drop = df_drop.rename(columns = {'character.class.name': 'class', 'character.spec.name': 'spec', 'character.region.name': 'region'})
df_drop

# %% [markdown]
# ## CSV Export

# %%
df_drop.to_csv('wowzin.csv')
